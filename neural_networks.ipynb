# %% [markdown]
# # Neural Network (MLP) for Cattle Milk Yield Prediction
#
# This notebook trains a fully connected neural network (MLP) to predict milk yield from a cleaned feature set.
#
#
#
# *   Standardized feature matrix with z score normalization
# *   Uses EarlyStopping and ReduceLROnPlateue to optimize training duration and learning rate
# *   80/20 train-validation split
# *   Retrains final model on full dataset with optimal epoch count
#
# Since neural networks can easily overfit, especially on tabular data, we implemented regularization and validation monitoring to ensure model stability and predictive accuracy.

# %%
import pandas as pd
import numpy as np
import time
import tensorflow as tf

from sklearn.model_selection import KFold, RandomizedSearchCV
from xgboost import XGBRegressor

# %% [markdown]
# ### Load and Prepare Data

# %%
# Option 1: local files
# train_path = "/content/cleaned_train_data.csv"
# test_path  = "/content/cleaned_test_data.csv"

# OPTION 2: Google Drive/Google Colab
from google.colab import drive
drive.mount("/content/drive")


train_path = "/content/drive/MyDrive/ml final/cleaned_train_data.csv"
test_path  = "/content/drive/MyDrive/ml final/cleaned_test_data.csv"

train = pd.read_csv(train_path)
test  = pd.read_csv(test_path)

print("Train shape:", train.shape)
print("Test shape :", test.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Train shape: (209926, 41)
# Test shape : (40000, 41)

# %% [markdown]
# We seperate features/targets, encode object columns, convert boolean columns to integers

# %%
TARGET = "Milk_Yield_L"
ID_COL = "Cattle_ID"

X = train.drop(columns=[TARGET, ID_COL])
y = train[TARGET]

X_test = test.drop(columns=[ID_COL], errors="ignore")

print("\nDtypes before encoding:")
print(X.dtypes)

obj_cols = X.select_dtypes(include=["object"]).columns.tolist()
print("\nObject columns to encode:", obj_cols)

for col in obj_cols:
    combined = pd.concat([X[col], X_test[col]], axis=0)
    codes, uniques = pd.factorize(combined)
    X[col] = codes[:len(X)]
    X_test[col] = codes[len(X):]

bool_cols = X.select_dtypes(include=["bool"]).columns.tolist()
if bool_cols:
    X[bool_cols] = X[bool_cols].astype(int)
    X_test[bool_cols] = X_test[bool_cols].astype(int)

print("\nDtypes after encoding:")
print(X.dtypes)
# Out:
# Dtypes before encoding:
# Age_Months                            int64
# Weight_kg                           float64
# Parity                                int64
# Lactation_Stage                       int64
# Days_in_Milk                          int64
# Feed_Type                            object
# Feed_Quantity_kg                    float64
# Feeding_Frequency                     int64
# Water_Intake_L                      float64
# Walking_Distance_km                 float64
# Grazing_Duration_hrs                float64
# Resting_Hours                       float64
# Ambient_Temperature_C               float64
# Humidity_percent                    float64
# Housing_Score                       float64
# FMD_Vaccine                           int64
# Brucellosis_Vaccine                   int64
# HS_Vaccine                            int64
# BQ_Vaccine                            int64
# Anthrax_Vaccine                       int64
# IBR_Vaccine                           int64
# BVD_Vaccine                           int64
# Rabies_Vaccine                        int64
# Previous_Week_Avg_Yield             float64
# Body_Condition_Score                float64
# Milking_Interval_hrs                  int64
# Farm_ID                               int64
# Mastitis                              int64
# Breed_Brown Swiss                      bool
# Breed_Brown Swiss                      bool
# Breed_Guernsey                         bool
# Breed_Holstein                         bool
# Breed_Holstien                         bool
# Breed_Jersey                           bool
# Management_System_Intensive            bool
# Management_System_Mixed                bool
# Management_System_Pastoral             bool
# Management_System_Semi_Intensive       bool
# Date_Ordinal                          int64
# dtype: object
#
# Object columns to encode: ['Feed_Type']
#
# Dtypes after encoding:
# Age_Months                            int64
# Weight_kg                           float64
# Parity                                int64
# Lactation_Stage                       int64
# Days_in_Milk                          int64
# Feed_Type                             int64
# Feed_Quantity_kg                    float64
# Feeding_Frequency                     int64
# Water_Intake_L                      float64
# Walking_Distance_km                 float64
# Grazing_Duration_hrs                float64
# Resting_Hours                       float64
# Ambient_Temperature_C               float64
# Humidity_percent                    float64
# Housing_Score                       float64
# FMD_Vaccine                           int64
# Brucellosis_Vaccine                   int64
# HS_Vaccine                            int64
# BQ_Vaccine                            int64
# Anthrax_Vaccine                       int64
# IBR_Vaccine                           int64
# BVD_Vaccine                           int64
# Rabies_Vaccine                        int64
# Previous_Week_Avg_Yield             float64
# Body_Condition_Score                float64
# Milking_Interval_hrs                  int64
# Farm_ID                               int64
# Mastitis                              int64
# Breed_Brown Swiss                     int64
# Breed_Brown Swiss                     int64
# Breed_Guernsey                        int64
# Breed_Holstein                        int64
# Breed_Holstien                        int64
# Breed_Jersey                          int64
# Management_System_Intensive           int64
# Management_System_Mixed               int64
# Management_System_Pastoral            int64
# Management_System_Semi_Intensive      int64
# Date_Ordinal                          int64
# dtype: object

# %% [markdown]
# ### Neural Network

# %% [markdown]
# We setup numpy arrays and apply feature standardization

# %%
X_test_nn_df = X_test[X.columns]
X_nn = X.astype("float32").values
y_nn = np.asarray(y, dtype="float32")
X_test_nn = X_test_nn_df.astype("float32").values

# standardize features
feat_mean = X_nn.mean(axis=0, keepdims=True)
feat_std = X_nn.std(axis=0, keepdims=True) + 1e-8

X_nn = (X_nn - feat_mean) / feat_std
X_test_nn = (X_test_nn - feat_mean) / feat_std

input_dim = X_nn.shape[1]
print("Input dim:", input_dim)
# Out:
# Input dim: 39

# %% [markdown]
# We setup an 80/20 train & validation split

# %%
rng = np.random.default_rng(42)
indices = rng.permutation(len(X_nn))
val_frac = 0.2
val_size = int(len(X_nn) * val_frac)

val_idx = indices[:val_size]
train_idx = indices[val_size:]

X_train_nn, X_val_nn = X_nn[train_idx], X_nn[val_idx]
y_train_nn, y_val_nn = y_nn[train_idx], y_nn[val_idx]

print("Train samples:", X_train_nn.shape[0])
print("Val samples  :", X_val_nn.shape[0])
# Out:
# Train samples: 167941
# Val samples  : 41985

# %% [markdown]
# We setup a fully-connected multi-layer perceptron which stacks dense layers with RELU activations to learn the nonlinear layers, while the dropout and batch normalizations are used to reduce overfitting.

# %%
def build_mlp(input_dim,
              hidden_units=(256, 128, 64),
              dropout=0.2,
              lr=1e-3):
    inputs = tf.keras.Input(shape=(input_dim,))
    x = inputs
    for units in hidden_units:
        x = tf.keras.layers.Dense(units, activation="relu")(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(dropout)(x)
    outputs = tf.keras.layers.Dense(1, activation="linear")(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="mse",
        metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse")],
    )
    return model

# %% [markdown]
# Initialize model and set hyperparameters/callbacks to improve training stability.

# %%
model = build_mlp(
    input_dim=input_dim,
    hidden_units=(256, 128, 64),
    dropout=0.2,
    lr=1e-3,
)

model.summary()

batch_size = 1024
epochs = 50

callbacks = [
    # used to stop training when RMSE stops improving as to reduce overfitting
    tf.keras.callbacks.EarlyStopping(
        monitor="val_rmse",
        patience=5,
        restore_best_weights=True,
        verbose=1,
    ),
    # reduces learning rate when progress is slowed
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_rmse",
        factor=0.5,
        patience=3,
        min_lr=1e-5,
        verbose=1,
    ),
]

print("Training NN...")
start_time = time.time()

history = model.fit(
    X_train_nn,
    y_train_nn,
    validation_data=(X_val_nn, y_val_nn),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=1,
)

elapsed_min = (time.time() - start_time) / 60
print(f"\nNN training finished in {elapsed_min:.2f} minutes.")

val_loss, val_rmse = model.evaluate(X_val_nn, y_val_nn, verbose=0)
print(f"\nValidation RMSE (NN): {val_rmse:.4f}")
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 39)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │        10,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,249 (208.00 KB)
#  Trainable params: 52,353 (204.50 KB)
#  Non-trainable params: 896 (3.50 KB)
# Training NN...
# Epoch 1/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 247.0498 - rmse: 15.7106 - val_loss: 146.1953 - val_rmse: 12.0911 - learning_rate: 0.0010
# Epoch 2/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 113.1106 - rmse: 10.5887 - val_loss: 30.9410 - val_rmse: 5.5625 - learning_rate: 0.0010
# Epoch 3/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 29.2592 - rmse: 5.4044 - val_loss: 19.4142 - val_rmse: 4.4062 - learning_rate: 0.0010
# Epoch 4/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 23.1953 - rmse: 4.8161 - val_loss: 19.0851 - val_rmse: 4.3686 - learning_rate: 0.0010
# Epoch 5/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 22.6277 - rmse: 4.7567 - val_loss: 18.8459 - val_rmse: 4.3412 - learning_rate: 0.0010
# Epoch 6/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 21.7980 - rmse: 4.6688 - val_loss: 18.7182 - val_rmse: 4.3264 - learning_rate: 0.0010
# Epoch 7/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.2900 - rmse: 4.6141 - val_loss: 18.7068 - val_rmse: 4.3251 - learning_rate: 0.0010
# Epoch 8/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 21.0656 - rmse: 4.5897 - val_loss: 18.6717 - val_rmse: 4.3211 - learning_rate: 0.0010
# Epoch 9/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.7878 - rmse: 4.5593 - val_loss: 18.6458 - val_rmse: 4.3181 - learning_rate: 0.0010
# Epoch 10/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.4802 - rmse: 4.5255 - val_loss: 18.5968 - val_rmse: 4.3124 - learning_rate: 0.0010
# Epoch 11/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.3539 - rmse: 4.5115 - val_loss: 18.5590 - val_rmse: 4.3080 - learning_rate: 0.0010
# Epoch 12/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.1141 - rmse: 4.4848 - val_loss: 18.5486 - val_rmse: 4.3068 - learning_rate: 0.0010
# Epoch 13/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.0124 - rmse: 4.4735 - val_loss: 18.5219 - val_rmse: 4.3037 - learning_rate: 0.0010
# Epoch 14/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.9282 - rmse: 4.4641 - val_loss: 18.5213 - val_rmse: 4.3036 - learning_rate: 0.0010
# Epoch 15/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.8950 - rmse: 4.4603 - val_loss: 18.5258 - val_rmse: 4.3042 - learning_rate: 0.0010
# Epoch 16/50
# 154/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.7477 - rmse: 4.4438
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.7460 - rmse: 4.4436 - val_loss: 18.5305 - val_rmse: 4.3047 - learning_rate: 0.0010
# Epoch 17/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.6241 - rmse: 4.4299 - val_loss: 18.5002 - val_rmse: 4.3012 - learning_rate: 5.0000e-04
# Epoch 18/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.4995 - rmse: 4.4158 - val_loss: 18.4949 - val_rmse: 4.3006 - learning_rate: 5.0000e-04
# Epoch 19/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.5278 - rmse: 4.4190 - val_loss: 18.4825 - val_rmse: 4.2991 - learning_rate: 5.0000e-04
# Epoch 20/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.5907 - rmse: 4.4261 - val_loss: 18.4915 - val_rmse: 4.3002 - learning_rate: 5.0000e-04
# Epoch 21/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.5032 - rmse: 4.4162 - val_loss: 18.4844 - val_rmse: 4.2994 - learning_rate: 5.0000e-04
# Epoch 22/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.5398 - rmse: 4.4204 - val_loss: 18.4727 - val_rmse: 4.2980 - learning_rate: 5.0000e-04
# Epoch 23/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.3531 - rmse: 4.3992 - val_loss: 18.4800 - val_rmse: 4.2988 - learning_rate: 5.0000e-04
# Epoch 24/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.4767 - rmse: 4.4132 - val_loss: 18.4751 - val_rmse: 4.2983 - learning_rate: 5.0000e-04
# Epoch 25/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.3960 - rmse: 4.4041 - val_loss: 18.4681 - val_rmse: 4.2974 - learning_rate: 5.0000e-04
# Epoch 26/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.4076 - rmse: 4.4054 - val_loss: 18.4542 - val_rmse: 4.2958 - learning_rate: 5.0000e-04
# Epoch 27/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.3588 - rmse: 4.3998 - val_loss: 18.4702 - val_rmse: 4.2977 - learning_rate: 5.0000e-04
# Epoch 28/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.2850 - rmse: 4.3914 - val_loss: 18.4558 - val_rmse: 4.2960 - learning_rate: 5.0000e-04
# Epoch 29/50
# 156/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.4165 - rmse: 4.4063
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.4098 - rmse: 4.4056 - val_loss: 18.4569 - val_rmse: 4.2961 - learning_rate: 5.0000e-04
# Epoch 30/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.3903 - rmse: 4.4034 - val_loss: 18.4623 - val_rmse: 4.2968 - learning_rate: 2.5000e-04
# Epoch 31/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.3767 - rmse: 4.4018 - val_loss: 18.4484 - val_rmse: 4.2952 - learning_rate: 2.5000e-04
# Epoch 32/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.1920 - rmse: 4.3808 - val_loss: 18.4438 - val_rmse: 4.2946 - learning_rate: 2.5000e-04
# Epoch 33/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.2155 - rmse: 4.3835 - val_loss: 18.4609 - val_rmse: 4.2966 - learning_rate: 2.5000e-04
# Epoch 34/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.2280 - rmse: 4.3850 - val_loss: 18.4422 - val_rmse: 4.2944 - learning_rate: 2.5000e-04
# Epoch 35/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.1050 - rmse: 4.3709 - val_loss: 18.4392 - val_rmse: 4.2941 - learning_rate: 2.5000e-04
# Epoch 36/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.1063 - rmse: 4.3710 - val_loss: 18.4415 - val_rmse: 4.2944 - learning_rate: 2.5000e-04
# Epoch 37/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.1654 - rmse: 4.3778 - val_loss: 18.4240 - val_rmse: 4.2923 - learning_rate: 2.5000e-04
# Epoch 38/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.3483 - rmse: 4.3986 - val_loss: 18.4199 - val_rmse: 4.2918 - learning_rate: 2.5000e-04
# Epoch 39/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.0589 - rmse: 4.3656 - val_loss: 18.4310 - val_rmse: 4.2931 - learning_rate: 2.5000e-04
# Epoch 40/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.0807 - rmse: 4.3681 - val_loss: 18.4324 - val_rmse: 4.2933 - learning_rate: 2.5000e-04
# Epoch 41/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.0442 - rmse: 4.3639 - val_loss: 18.4163 - val_rmse: 4.2914 - learning_rate: 2.5000e-04
# Epoch 42/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.1059 - rmse: 4.3710 - val_loss: 18.4294 - val_rmse: 4.2929 - learning_rate: 2.5000e-04
# Epoch 43/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.1414 - rmse: 4.3751 - val_loss: 18.4172 - val_rmse: 4.2915 - learning_rate: 2.5000e-04
# Epoch 44/50
# 154/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.1940 - rmse: 4.3811
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.1883 - rmse: 4.3804 - val_loss: 18.4182 - val_rmse: 4.2916 - learning_rate: 2.5000e-04
# Epoch 45/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.0614 - rmse: 4.3659 - val_loss: 18.4127 - val_rmse: 4.2910 - learning_rate: 1.2500e-04
# Epoch 46/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.1890 - rmse: 4.3805 - val_loss: 18.4060 - val_rmse: 4.2902 - learning_rate: 1.2500e-04
# Epoch 47/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 18.9854 - rmse: 4.3572 - val_loss: 18.3986 - val_rmse: 4.2894 - learning_rate: 1.2500e-04
# Epoch 48/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.0599 - rmse: 4.3658 - val_loss: 18.4040 - val_rmse: 4.2900 - learning_rate: 1.2500e-04
# Epoch 49/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 18.9539 - rmse: 4.3536 - val_loss: 18.4005 - val_rmse: 4.2896 - learning_rate: 1.2500e-04
# Epoch 50/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.0033 - rmse: 4.3592 - val_loss: 18.3941 - val_rmse: 4.2888 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 50.
#
# NN training finished in 0.77 minutes.
#
# Validation RMSE (NN): 4.2888

# %% [markdown]
# We find the optimal epoch episode number right before EarlyStopping was called and retrain a model on the entire dataset with that epoch number.

# %%
best_epochs = len(history.history["rmse"])

print(f"\nTraining final NN on all data for {best_epochs} epochs...")
final_model_nn = build_mlp(
    input_dim=input_dim,
    hidden_units=(256, 128, 64),
    dropout=0.2,
    lr=1e-3,
)

final_model_nn.fit(
    X_nn,
    y_nn,
    epochs=best_epochs,
    batch_size=batch_size,
    verbose=1,
)
# Out:
# Training final NN on all data for 50 epochs...
# Epoch 1/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 238.9706 - rmse: 15.4451
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 73.0874 - rmse: 8.4925
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.8789 - rmse: 4.8863
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.2230 - rmse: 4.7141
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.6425 - rmse: 4.6521
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0069 - rmse: 4.5833
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5897 - rmse: 4.5376
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.2929 - rmse: 4.5047
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.1900 - rmse: 4.4933
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9462 - rmse: 4.4661
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.6730 - rmse: 4.4354
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.7863 - rmse: 4.4481
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.5998 - rmse: 4.4272
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.4782 - rmse: 4.4134
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.4823 - rmse: 4.4139
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.3862 - rmse: 4.4030
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.4271 - rmse: 4.4076
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.3882 - rmse: 4.4032
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2322 - rmse: 4.3854
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.1627 - rmse: 4.3775
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2254 - rmse: 4.3847
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2478 - rmse: 4.3872
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.1880 - rmse: 4.3804
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2448 - rmse: 4.3868
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.0116 - rmse: 4.3602
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.0793 - rmse: 4.3680
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2333 - rmse: 4.3855
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.1216 - rmse: 4.3728
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.9364 - rmse: 4.3516
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.9873 - rmse: 4.3574
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.8609 - rmse: 4.3429
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.0162 - rmse: 4.3607
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.9658 - rmse: 4.3549
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 18.8393 - rmse: 4.3404
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 18.8916 - rmse: 4.3464
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 18.9505 - rmse: 4.3532
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.7990 - rmse: 4.3358
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.8712 - rmse: 4.3441
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.7532 - rmse: 4.3305
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.7331 - rmse: 4.3282
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.8243 - rmse: 4.3387
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.8171 - rmse: 4.3378
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.7854 - rmse: 4.3342
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.6727 - rmse: 4.3212
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.7782 - rmse: 4.3334
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.6486 - rmse: 4.3184
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.5875 - rmse: 4.3113
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.7170 - rmse: 4.3263
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.4653 - rmse: 4.2971
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.5982 - rmse: 4.3125

# %% [markdown]
# We produce and save our submission

# %%
nn_train_preds = final_model_nn.predict(X_nn, batch_size=1024).squeeze()
print("  NN Train RMSE:       ", np.sqrt(np.mean((y - nn_train_preds)**2)))


test_preds_nn = final_model_nn.predict(X_test_nn, batch_size=batch_size).squeeze()

nn_submission = pd.DataFrame({
    "Cattle_ID": test["Cattle_ID"],
    "Milk_Yield_L": test_preds_nn,
})

nn_submission_path = "/content/nn_submission.csv"
nn_submission.to_csv(nn_submission_path, index=False)

print(f"\nSaved NN submission to: {nn_submission_path}")
nn_submission.head()
# Out:
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#   NN Train RMSE:        4.17654700219103
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#
# Saved NN submission to: /content/nn_submission.csv
#    Cattle_ID  Milk_Yield_L
# 0          1     18.925587
# 1          2     10.408438
# 2          3     22.020819
# 3          4     14.712931
# 4          5     17.246048
